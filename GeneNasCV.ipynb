# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/EvolutionCompute/geneNas
# Out:
# /content/drive/MyDrive/EvolutionCompute/geneNas

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/EvolutionCompute

# %%
# !ls
# Out:
# geneNas  GeneNasCV.ipynb

# %%
# !pip install datasets
# !pip install pytorch_lightning
# !pip install transformers
# !pip install colabcode
# Out:
# ...
#      |████████████████████████████████| 290 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 132 kB 52.6 MB/s
# ...
#      |████████████████████████████████| 243 kB 45.7 MB/s
# ...
#      |████████████████████████████████| 59 kB 6.7 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 37.7 MB/s
# ...
#      |████████████████████████████████| 160 kB 48.9 MB/s
# ...
#      |████████████████████████████████| 271 kB 51.3 MB/s
# ...
#      |████████████████████████████████| 192 kB 53.0 MB/s
# ...
#      |████████████████████████████████| 1.0 MB 4.1 MB/s
# ...
#      |████████████████████████████████| 829 kB 34.2 MB/s
# ...
#      |████████████████████████████████| 596 kB 48.9 MB/s
# ...
#      |████████████████████████████████| 329 kB 51.2 MB/s
# ...
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=67350a13a75d3fb7a0dad82cb936a494d40c2bcb19736f4797a4255d4aef9821
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
# Successfully built future
# ...

# %% [markdown]
# #Open VS Code in Colab

# %% [markdown]
# Ctrl + Shift + ` to open Terminal

# %%
from colabcode import ColabCode
ColabCode(port=10000,mount_drive = True)
# Out:
# Code Server can be accessed on: NgrokTunnel: "https://78a6-34-71-123-239.ngrok.io" -> "http://localhost:10000"
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [2021-11-07T17:31:58.761Z] info  code-server 3.10.2 387b12ef4ca404ffd39d84834e1f0776e9e3c005
# [2021-11-07T17:31:58.763Z] info  Using user-data-dir ~/.local/share/code-server
# [2021-11-07T17:31:58.783Z] info  Using config file ~/.config/code-server/config.yaml
# [2021-11-07T17:31:58.783Z] info  HTTP server listening on http://127.0.0.1:10000
# [2021-11-07T17:31:58.783Z] info    - Authentication is disabled
# [2021-11-07T17:31:58.785Z] info    - Not serving HTTPS

# %% [markdown]
# #Running command

# %%
# %cd ..
# Out:
# /content/drive/My Drive/EvolutionCompute

# %%
# !git add .

# %%
# !git config --global user.email "huydang2k@gmail.com"

# %%
# !git config --global user.name "huydang2k"

# %%
# !git commit -m "cv problem"
# Out:
# [master (root-commit) 92da215] cv problem
#  72 files changed, 4851 insertions(+)
#  create mode 100644 GeneNasCV.ipynb
#  create mode 100644 geneNas/.gitignore
#  create mode 100644 geneNas/README.md
#  create mode 100644 geneNas/cache_dataset.py
#  create mode 100644 geneNas/cache_embed.py
#  create mode 100644 geneNas/demo.py
#  create mode 100644 geneNas/eval_baseline.py
#  create mode 100644 geneNas/eval_best_network.py
#  create mode 100644 geneNas/eval_chromosome.py
#  create mode 100644 geneNas/evolution/__init__.py
#  create mode 100644 geneNas/evolution/__pycache__/__init__.cpython-37.pyc
#  create mode 100644 geneNas/evolution/__pycache__/gene_type.cpython-37.pyc
#  create mode 100644 geneNas/evolution/__pycache__/operator.cpython-37.pyc
#  create mode 100644 geneNas/evolution/__pycache__/optimizer.cpython-37.pyc
#  create mode 100644 geneNas/evolution/gene_type.py
#  create mode 100644 geneNas/evolution/operator.py
#  create mode 100644 geneNas/evolution/optimizer.py
# ...

# %%
# !ls
# Out:
# geneNas  GeneNasCV.ipynb

# %%
# %cd ..
# Out:
# /content/drive/My Drive/EvolutionCompute

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/EvolutionCompute/.git/

# %%
# !git remote set-url  origin https://huydang2k:nbfWXK69@github.com/huydang2k/genenas_cv_implement

# %%
# !git push --set-upstream origin master
# Out:
# remote: Support for password authentication was removed on August 13, 2021. Please use a personal access token instead.
# remote: Please see https://github.blog/2020-12-15-token-authentication-requirements-for-git-operations/ for more information.
# fatal: Authentication failed for 'https://huydang2k:nbfWXK69@github.com/huydang2k/genenas_cv_implement/'
