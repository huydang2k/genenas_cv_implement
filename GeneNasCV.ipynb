# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/hieule88/geneNas
# Out:
# Cloning into 'geneNas'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 53 (delta 16), reused 40 (delta 9), pack-reused 0
# Unpacking objects: 100% (53/53), done.

# %%
# %cd EvolutionCompute/geneNas
# Out:
# /content/drive/MyDrive/EvolutionCompute/geneNas

# %%
# !ls
# Out:
# cache_dataset.py      extract_chromosome_from_symbol.py  main_rwe_multi_obj.py
# cache_embed.py	      extract_chromosome.py		 main_rwe.py
# demo.py		      extract_symbol.py			 network
# eval_baseline.py      install.sh			 problem
# eval_best_network.py  install.sh.1			 README.md
# eval_chromosome.py    main_multi_obj.py			 requirements.txt
# evolution	      main_rwe_multi_obj_no_train.py	 util

# %%
# !pip install datasets
# !pip install pytorch_lightning
# !pip install transformers
# !pip install colabcode
# Out:
# ...
#      |████████████████████████████████| 290 kB 5.2 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 40.8 MB/s
# ...
#      |████████████████████████████████| 125 kB 44.0 MB/s
# ...
#      |████████████████████████████████| 56 kB 4.8 MB/s
# ...
#      |████████████████████████████████| 243 kB 38.2 MB/s
# ...
#      |████████████████████████████████| 271 kB 42.6 MB/s
# ...
#      |████████████████████████████████| 160 kB 50.5 MB/s
# ...
#      |████████████████████████████████| 925 kB 5.3 MB/s
# ...
#      |████████████████████████████████| 329 kB 44.1 MB/s
# ...
#      |████████████████████████████████| 596 kB 40.6 MB/s
# ...
#      |████████████████████████████████| 829 kB 40.2 MB/s
# ...
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=cbfa49acc2c7763b582313b48666ddbd1e5bbede5e9926cbe3346d01e7432f5e
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
# Successfully built future
# ...
#   Attempting uninstall: PyYAML
# ...

# %% [markdown]
# #Open VS Code in Colab

# %%
from colabcode import ColabCode
ColabCode(port=10000,mount_drive = True)
# Out:
# Code Server can be accessed on: NgrokTunnel: "https://a0fe-34-136-246-101.ngrok.io" -> "http://localhost:10000"
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [2021-10-31T10:50:30.827Z] info  code-server 3.10.2 387b12ef4ca404ffd39d84834e1f0776e9e3c005
# [2021-10-31T10:50:30.828Z] info  Using user-data-dir ~/.local/share/code-server
# [2021-10-31T10:50:30.850Z] info  Using config file ~/.config/code-server/config.yaml
# [2021-10-31T10:50:30.850Z] info  HTTP server listening on http://127.0.0.1:10000
# [2021-10-31T10:50:30.851Z] info    - Authentication is disabled
# [2021-10-31T10:50:30.851Z] info    - Not serving HTTPS
# [IPC Library: Pty Host]  INFO Persistent process "1": Replaying 2369 chars and 1 size events

# %% [markdown]
# #Running command

# %%
# !python -W ignore main_rwe_multi_obj_no_train.py  --gpus 1 --model_name_or_path distilbert-base-uncased --task_name trec --max_epochs 1  --popsize 10 --num_iter 100 --train_batch_size 128 --eval_batch_size 128  --h_main 6 --h_adf 4
# Out:
# 100% 2/2 [00:00<00:00, 635.50it/s]
# 100% 2/2 [00:00<00:00, 674.65it/s]
# 100% 1/1 [00:00<00:00, 16.11ba/s]
# CHROMOSOME: ['leaky_relu', 'blending', 'element_wise_sum', 'element_wise_product', 'leaky_relu', 'linear', 'x3', 'x3', 'x2', 'x1', 'x3', 'x1', 'x3', 'x3', 'x1', 'x3', 'x3', 'x1', 'x3', 'blending', 'blending', 'concat', 'concat', 'a1', 'a2', 'x1', 'x2', 'x3', 'x2', 'x2', 'x1', 'x1', 'x1', 'x1', 'x1', 'x2', 'x1', 'x1', 'linear', 'linear', 'sigmoid', 'linear', 't2', 't2', 't2', 't2', 't3', 't1', 't3', 't2', 't1', 'element_wise_product', 'element_wise_product', 'concat', 'leaky_relu', 't1', 't3', 't2', 't3', 't3', 't1', 't2', 't1', 't3']
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...
